# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("kunalgupta2616/flickr-8k-images-with-captions")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/flickr-8k-images-with-captions

# %%
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, add
from tensorflow.keras.layers import Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from sklearn.model_selection import train_test_split
from PIL import Image
from tqdm import tqdm_notebook
from collections import Counter

# %%
images_directory = '/root/.cache/kagglehub/datasets/kunalgupta2616/flickr-8k-images-with-captions/versions/1/Images/'
captions_path = '/root/.cache/kagglehub/datasets/kunalgupta2616/flickr-8k-images-with-captions/versions/1/captions.txt'
def load_captions(file_path):
    with open(file_path, 'r') as f:
        captions = f.readlines()
        captions = [caption.lower() for caption in captions[1:]]
    return captions

def tokenize_captions(captions):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(captions)
    return tokenizer

captions = load_captions(captions_path)
captions[:15:3]
# Out:
# ['1000268201_693b08cb0e.jpg,a child in a pink dress is climbing up a set of stairs in an entry way .\n',
#  '1000268201_693b08cb0e.jpg,a little girl climbing the stairs to her playhouse .\n',
#  '1001773457_577c3a7d70.jpg,a black dog and a tri-colored dog playing with each other on the road .\n',
#  '1001773457_577c3a7d70.jpg,two dogs on pavement moving toward each other .\n',
#  '1002674143_1b742ab4b8.jpg,a small girl in the grass plays with fingerpaints in front of a white canvas with a rainbow on it .\n']

# %%
len(captions)
# Out:
# 40455

# %%
import re
def clean_text(text):
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

cleaned_captions = [clean_text(caption.split(',')[1]) for caption in captions]
cleaned_captions[:15:2]
# Out:
# ['a child in a pink dress is climbing up a set of stairs in an entry way',
#  'a little girl climbing into a wooden playhouse',
#  'a little girl in a pink dress going into a wooden cabin',
#  'a black dog and a tricolored dog playing with each other on the road',
#  'two dogs of different breeds looking at each other on the road',
#  'a little girl covered in paint sits in front of a painted rainbow with her hands in a bowl',
#  'a small girl in the grass plays with fingerpaints in front of a white canvas with a rainbow on it',
#  'young girl with pigtails painting outside in the grass']

# %%
len(cleaned_captions)
# Out:
# 40455

# %%
captions_IDs = []
for i in range(len(cleaned_captions)):
    item = captions[i].split(',')[0]+'\t'+'start '+cleaned_captions[i]+' end\n'
    captions_IDs.append(item)

captions_IDs[:20:3], len(captions_IDs)
# Out:
# (['1000268201_693b08cb0e.jpg\tstart a child in a pink dress is climbing up a set of stairs in an entry way end\n',
#   '1000268201_693b08cb0e.jpg\tstart a little girl climbing the stairs to her playhouse end\n',
#   '1001773457_577c3a7d70.jpg\tstart a black dog and a tricolored dog playing with each other on the road end\n',
#   '1001773457_577c3a7d70.jpg\tstart two dogs on pavement moving toward each other end\n',
#   '1002674143_1b742ab4b8.jpg\tstart a small girl in the grass plays with fingerpaints in front of a white canvas with a rainbow on it end\n',
#   '1003163366_44323f5815.jpg\tstart a man lays on a bench while his dog sits by him end\n',
#   '1003163366_44323f5815.jpg\tstart a shirtless man lies on a park bench with his dog end\n'],
#  40455)

# %%
def visualaization(data, num_of_images):
    captions_dictionary = {}
    for item in data[100:100+(num_of_images)*5]:
        image_id, caption = item.split('\t')
        if image_id not in captions_dictionary:
            captions_dictionary[image_id] = []
        captions_dictionary[image_id].append(caption)
    else:
        list_captions = [x for x in captions_dictionary.items()]

    count = 1
    fig = plt.figure(figsize=(10,20))
    for filename in list(captions_dictionary.keys()):
        captions = captions_dictionary[filename]
        image_load = load_img(images_directory+filename, target_size=(199,199,3))

        ax = fig.add_subplot(num_of_images,2,count,xticks=[],yticks=[])
        ax.imshow(image_load)
        count += 1

        ax = fig.add_subplot(num_of_images,2,count)
        plt.axis('off')
        ax.plot()
        ax.set_xlim(0,1)
        ax.set_ylim(0,len(captions))
        for i, caption in enumerate(captions):
            ax.text(0,i,caption,fontsize=20)
        count += 1
    plt.show()

visualaization(captions_IDs, 5)

# %%
def captions_length(data):
    plt.figure(figsize=(15, 7), dpi=300)
    sns.set_style('darkgrid')
    sns.histplot(x=[len(x.split(' ')) for x in data], kde=True, binwidth=1)
    plt.title('Captions length histogram', fontsize=15, fontweight='bold')
    plt.xticks(fontweight='bold')
    plt.yticks(fontweight='bold')
    plt.xlabel('Length', fontweight='bold')
    plt.ylabel('Freaquency', fontweight='bold')
    plt.show()

captions_length(cleaned_captions)

# %%
tokenizer = tokenize_captions(cleaned_captions)
tokenizer.word_index
# Out:
# {'a': 1,
#  'in': 2,
#  'the': 3,
#  'on': 4,
#  'is': 5,
#  'and': 6,
#  'dog': 7,
#  'with': 8,
#  'man': 9,
#  'of': 10,
#  'two': 11,
#  'white': 12,
#  'black': 13,
#  'boy': 14,
#  'are': 15,
#  'woman': 16,
#  'girl': 17,
#  'to': 18,
#  'wearing': 19,
#  'people': 20,
#  'at': 21,
#  'water': 22,
#  'young': 23,
#  'red': 24,
#  'brown': 25,
#  'an': 26,
#  'his': 27,
#  'blue': 28,
#  'dogs': 29,
#  'running': 30,
#  'through': 31,
#  'playing': 32,
#  'while': 33,
#  'down': 34,
#  'little': 35,
#  'shirt': 36,
#  'standing': 37,
#  'ball': 38,
#  'grass': 39,
#  'person': 40,
#  'child': 41,
#  'snow': 42,
#  'jumping': 43,
#  'over': 44,
#  'three': 45,
#  'front': 46,
#  'sitting': 47,
#  'small': 48,
#  'field': 49,
#  'up': 50,
#  'holding': 51,
#  'large': 52,
#  'group': 53,
#  'by': 54,
#  'green': 55,
#  'yellow': 56,
#  'children': 57,
#  'walking': 58,
#  'men': 59,
#  'her': 60,
#  'into': 61,
#  'beach': 62,
#  'air': 63,
#  'near': 64,
#  'jumps': 65,
#  'mouth': 66,
#  'street': 67,
#  'runs': 68,
#  'for': 69,
#  'another': 70,
#  'riding': 71,
#  'from': 72,
#  'its': 73,
#  'as': 74,
#  'bike': 75,
#  'stands': 76,
#  'girls': 77,
#  'one': 78,
#  'outside': 79,
#  'rock': 80,
#  'player': 81,
#  'off': 82,
#  'next': 83,
#  'play': 84,
#  'out': 85,
#  'pink': 86,
#  'orange': 87,
#  'looking': 88,
#  'pool': 89,
#  'other': 90,
#  'their': 91,
#  'camera': 92,
#  'boys': 93,
#  'jacket': 94,
#  'women': 95,
#  'hat': 96,
#  'around': 97,
#  'some': 98,
#  'dirt': 99,
#  'soccer': 100,
#  'sits': 101,
#  'behind': 102,
#  'toy': 103,
#  'dressed': 104,
#  'mountain': 105,
#  'wall': 106,
#  'walks': 107,
#  'has': 108,
#  'plays': 109,
#  'along': 110,
#  'stand': 111,
#  'crowd': 112,
#  'climbing': 113,
#  'looks': 114,
#  'park': 115,
#  'four': 116,
#  'building': 117,
#  'football': 118,
#  'across': 119,
#  'top': 120,
#  'holds': 121,
#  'rides': 122,
#  'ocean': 123,
#  'grassy': 124,
#  'sand': 125,
#  'face': 126,
#  'background': 127,
#  'smiling': 128,
#  'stick': 129,
#  'swimming': 130,
#  'hill': 131,
#  'skateboard': 132,
#  'car': 133,
#  'doing': 134,
#  'baby': 135,
#  'tennis': 136,
#  'bicycle': 137,
#  'picture': 138,
#  'together': 139,
#  'snowy': 140,
#  'each': 141,
#  'carrying': 142,
#  'jump': 143,
#  'tree': 144,
#  'basketball': 145,
#  'that': 146,
#  'hair': 147,
#  's': 148,
#  'tan': 149,
#  'road': 150,
#  'trick': 151,
#  'race': 152,
#  'it': 153,
#  'area': 154,
#  'swing': 155,
#  'bench': 156,
#  'game': 157,
#  'head': 158,
#  'sidewalk': 159,
#  'catch': 160,
#  'back': 161,
#  'him': 162,
#  'shorts': 163,
#  'sit': 164,
#  'run': 165,
#  'kids': 166,
#  'helmet': 167,
#  'dress': 168,
#  'ground': 169,
#  'something': 170,
#  'being': 171,
#  'frisbee': 172,
#  'fence': 173,
#  'lake': 174,
#  'hand': 175,
#  'wave': 176,
#  'skateboarder': 177,
#  'path': 178,
#  'ramp': 179,
#  'several': 180,
#  'city': 181,
#  'purple': 182,
#  'walk': 183,
#  'there': 184,
#  'slide': 185,
#  'covered': 186,
#  'side': 187,
#  'baseball': 188,
#  'players': 189,
#  'posing': 190,
#  'track': 191,
#  'wooden': 192,
#  'high': 193,
#  'long': 194,
#  'big': 195,
#  'boat': 196,
#  'sunglasses': 197,
#  'watches': 198,
#  'uniform': 199,
#  'coat': 200,
#  'look': 201,
#  'rocks': 202,
#  'ride': 203,
#  'trees': 204,
#  'table': 205,
#  'motorcycle': 206,
#  'couple': 207,
#  'beside': 208,
#  'snowboarder': 209,
#  'rope': 210,
#  'watching': 211,
#  'under': 212,
#  'suit': 213,
#  'towards': 214,
#  'pants': 215,
#  'dark': 216,
#  'sign': 217,
#  'grey': 218,
#  'rocky': 219,
#  'hands': 220,
#  'river': 221,
#  'horse': 222,
#  'does': 223,
#  'arms': 224,
#  'racing': 225,
#  'lady': 226,
#  'watch': 227,
#  'ice': 228,
#  'them': 229,
#  'older': 230,
#  'above': 231,
#  'colorful': 232,
#  'woods': 233,
#  'pose': 234,
#  'jeans': 235,
#  'guy': 236,
#  'who': 237,
#  'midair': 238,
#  'onto': 239,
#  'he': 240,
#  'striped': 241,
#  'asian': 242,
#  'leaps': 243,
#  'playground': 244,
#  'climbs': 245,
#  'hockey': 246,
#  'performing': 247,
#  'taking': 248,
#  'cliff': 249,
#  'mountains': 250,
#  'yard': 251,
#  'collar': 252,
#  'against': 253,
#  'blonde': 254,
#  'surfer': 255,
#  'bird': 256,
#  'body': 257,
#  'blond': 258,
#  'glasses': 259,
#  'smiles': 260,
#  'laying': 261,
#  'kid': 262,
#  'rider': 263,
#  'chasing': 264,
#  'skier': 265,
#  'many': 266,
#  'team': 267,
#  'fountain': 268,
#  'after': 269,
#  'during': 270,
#  'biker': 271,
#  'wet': 272,
#  'old': 273,
#  'cap': 274,
#  'inside': 275,
#  'toddler': 276,
#  'takes': 277,
#  'open': 278,
#  'brick': 279,
#  'edge': 280,
#  'flying': 281,
#  'very': 282,
#  'colored': 283,
#  'someone': 284,
#  'guitar': 285,
#  'shore': 286,
#  'trying': 287,
#  'outdoors': 288,
#  'outfit': 289,
#  'forest': 290,
#  'five': 291,
#  'surrounded': 292,
#  'middle': 293,
#  'hanging': 294,
#  'night': 295,
#  'away': 296,
#  'bed': 297,
#  'light': 298,
#  'talking': 299,
#  'pole': 300,
#  'whilst': 301,
#  'others': 302,
#  'object': 303,
#  'floor': 304,
#  'tshirt': 305,
#  'surfboard': 306,
#  'steps': 307,
#  'going': 308,
#  'past': 309,
#  'line': 310,
#  'backpack': 311,
#  'toward': 312,
#  'about': 313,
#  'making': 314,
#  'trail': 315,
#  'swinging': 316,
#  'this': 317,
#  'eating': 318,
#  'nearby': 319,
#  'poses': 320,
#  'haired': 321,
#  'gray': 322,
#  'tall': 323,
#  'arm': 324,
#  'dancing': 325,
#  'flowers': 326,
#  'bridge': 327,
#  'day': 328,
#  'waves': 329,
#  'leaves': 330,
#  'clothes': 331,
#  'course': 332,
#  'fighting': 333,
#  'leaping': 334,
#  'sky': 335,
#  'board': 336,
#  'shallow': 337,
#  'window': 338,
#  'costume': 339,
#  'outdoor': 340,
#  'plastic': 341,
#  'carries': 342,
#  'house': 343,
#  'leash': 344,
#  'splashing': 345,
#  'room': 346,
#  'chair': 347,
#  'legs': 348,
#  'climber': 349,
#  'bag': 350,
#  'stone': 351,
#  'catches': 352,
#  'obstacle': 353,
#  'clothing': 354,
#  'all': 355,
#  'bright': 356,
#  'swings': 357,
#  'ready': 358,
#  'between': 359,
#  'getting': 360,
#  'skateboarding': 361,
#  'they': 362,
#  'sliding': 363,
#  'bathing': 364,
#  'sweater': 365,
#  'trampoline': 366,
#  'sled': 367,
#  'gear': 368,
#  'concrete': 369,
#  'adult': 370,
#  'railing': 371,
#  'wears': 372,
#  'mud': 373,
#  'waiting': 374,
#  'skiing': 375,
#  'stream': 376,
#  'metal': 377,
#  'lawn': 378,
#  'male': 379,
#  'winter': 380,
#  'stairs': 381,
#  'fire': 382,
#  'pulling': 383,
#  'uniforms': 384,
#  'shirts': 385,
#  'sandy': 386,
#  'catching': 387,
#  'gets': 388,
#  'set': 389,
#  'store': 390,
#  'jersey': 391,
#  'tries': 392,
#  'train': 393,
#  'lot': 394,
#  'golden': 395,
#  'swims': 396,
#  'bar': 397,
#  'adults': 398,
#  'fishing': 399,
#  'rail': 400,
#  'drink': 401,
#  'tricks': 402,
#  'shirtless': 403,
#  'get': 404,
#  'flies': 405,
#  'female': 406,
#  'smile': 407,
#  'distance': 408,
#  'overlooking': 409,
#  'couch': 410,
#  'busy': 411,
#  'tongue': 412,
#  'sun': 413,
#  'makes': 414,
#  'chases': 415,
#  'performs': 416,
#  'throwing': 417,
#  'surfing': 418,
#  'trunks': 419,
#  'ski': 420,
#  'lying': 421,
#  'number': 422,
#  'puppy': 423,
#  'puddle': 424,
#  'dock': 425,
#  'huge': 426,
#  'pond': 427,
#  'swim': 428,
#  'drinking': 429,
#  'wooded': 430,
#  'animal': 431,
#  'vest': 432,
#  'flag': 433,
#  'tire': 434,
#  'horses': 435,
#  'bubbles': 436,
#  'upside': 437,
#  'photo': 438,
#  'leaning': 439,
#  'cellphone': 440,
#  'slides': 441,
#  'she': 442,
#  'kayak': 443,
#  'eyes': 444,
#  'snowboard': 445,
#  'truck': 446,
#  'flip': 447,
#  'laughing': 448,
#  'nose': 449,
#  'sunset': 450,
#  'shopping': 451,
#  'waterfall': 452,
#  'right': 453,
#  'american': 454,
#  'equipment': 455,
#  'reading': 456,
#  'view': 457,
#  'wetsuit': 458,
#  'family': 459,
#  'hold': 460,
#  'bat': 461,
#  'greyhound': 462,
#  'stunt': 463,
#  'food': 464,
#  'bikes': 465,
#  'elderly': 466,
#  'hats': 467,
#  'climb': 468,
#  'restaurant': 469,
#  'lone': 470,
#  'life': 471,
#  'or': 472,
#  'coming': 473,
#  'hurdle': 474,
#  'skis': 475,
#  'goal': 476,
#  'shoes': 477,
#  'like': 478,
#  'hiker': 479,
#  'harness': 480,
#  'left': 481,
#  'deep': 482,
#  'skating': 483,
#  'feet': 484,
#  'tent': 485,
#  'biting': 486,
#  'cart': 487,
#  'scarf': 488,
#  'setting': 489,
#  'no': 490,
#  'dry': 491,
#  'mask': 492,
#  'muddy': 493,
#  'guys': 494,
#  'take': 495,
#  'bmx': 496,
#  'closeup': 497,
#  'court': 498,
#  'fight': 499,
#  'vehicle': 500,
#  'umbrella': 501,
#  'six': 502,
#  'crowded': 503,
#  'sweatshirt': 504,
#  'pile': 505,
#  'skate': 506,
#  'dresses': 507,
#  'raft': 508,
#  'falling': 509,
#  'bus': 510,
#  'german': 511,
#  'structure': 512,
#  'ledge': 513,
#  'have': 514,
#  'diving': 515,
#  'tank': 516,
#  'driving': 517,
#  'surf': 518,
#  'teenage': 519,
#  'paper': 520,
#  'cyclist': 521,
#  'slope': 522,
#  'cement': 523,
#  'bags': 524,
#  'canoe': 525,
#  'inflatable': 526,
#  'airborne': 527,
#  'flags': 528,
#  'be': 529,
#  'cigarette': 530,
#  'book': 531,
#  'subway': 532,
#  'skirt': 533,
#  'goes': 534,
#  'splashes': 535,
#  'turn': 536,
#  'wood': 537,
#  'kick': 538,
#  'costumes': 539,
#  'shepherd': 540,
#  'fallen': 541,
#  'jackets': 542,
#  'shaking': 543,
#  'dance': 544,
#  'kicking': 545,
#  'bottle': 546,
#  'buildings': 547,
#  'both': 548,
#  'parking': 549,
#  'faces': 550,
#  'tunnel': 551,
#  'sports': 552,
#  'ears': 553,
#  'gathered': 554,
#  'goggles': 555,
#  'band': 556,
#  'hit': 557,
#  'balls': 558,
#  'microphone': 559,
#  'ring': 560,
#  'bikini': 561,
#  'parade': 562,
#  'chairs': 563,
#  'throws': 564,
#  'kicks': 565,
#  'pictures': 566,
#  'piece': 567,
#  'bicyclist': 568,
#  'full': 569,
#  'hiking': 570,
#  'beard': 571,
#  'stage': 572,
#  'bull': 573,
#  'rugby': 574,
#  'painted': 575,
#  'backyard': 576,
#  'smaller': 577,
#  'blanket': 578,
#  'silver': 579,
#  'outfits': 580,
#  'event': 581,
#  'blowing': 582,
#  'cars': 583,
#  'sunny': 584,
#  'steep': 585,
#  'swimsuit': 586,
#  'cat': 587,
#  'box': 588,
#  'leather': 589,
#  'surface': 590,
#  'statue': 591,
#  'low': 592,
#  'drinks': 593,
#  'scooter': 594,
#  'short': 595,
#  'glass': 596,
#  'sticks': 597,
#  'stuffed': 598,
#  'bald': 599,
#  'suits': 600,
#  'held': 601,
#  'volleyball': 602,
#  'graffiti': 603,
#  'smoking': 604,
#  'sleeping': 605,
#  'pushing': 606,
#  'using': 607,
#  'wheel': 608,
#  'wrestling': 609,
#  'throw': 610,
#  'pointing': 611,
#  'cow': 612,
#  'staring': 613,
#  'paint': 614,
#  'net': 615,
#  'leans': 616,
#  'crossing': 617,
#  'hugging': 618,
#  'corner': 619,
#  'fluffy': 620,
#  'tube': 621,
#  'door': 622,
#  'attempting': 623,
#  'few': 624,
#  'bucket': 625,
#  'hind': 626,
#  'motorcyclist': 627,
#  'lays': 628,
#  'make': 629,
#  'party': 630,
#  'boots': 631,
#  'wrestle': 632,
#  'flower': 633,
#  'hangs': 634,
#  'puppies': 635,
#  'show': 636,
#  'bunch': 637,
#  'same': 638,
#  'police': 639,
#  'snowboarding': 640,
#  'cowboy': 641,
#  'log': 642,
#  'beautiful': 643,
#  'wading': 644,
#  'cup': 645,
#  'teams': 646,
#  'sheep': 647,
#  'leg': 648,
#  'competition': 649,
#  'sprinkler': 650,
#  'eats': 651,
#  'fast': 652,
#  'underwater': 653,
#  'bicycles': 654,
#  'furry': 655,
#  'attempts': 656,
#  'spectators': 657,
#  'softball': 658,
#  'gather': 659,
#  'racetrack': 660,
#  'garden': 661,
#  'attached': 662,
#  'beige': 663,
#  'dances': 664,
#  'fish': 665,
#  'gym': 666,
#  'go': 667,
#  'kissing': 668,
#  'hoop': 669,
#  'desert': 670,
#  'end': 671,
#  'motocross': 672,
#  'racer': 673,
#  'phone': 674,
#  'poles': 675,
#  'shot': 676,
#  'racket': 677,
#  'below': 678,
#  'seat': 679,
#  'sticking': 680,
#  'handstand': 681,
#  'clear': 682,
#  'pushes': 683,
#  'rolling': 684,
#  'points': 685,
#  'way': 686,
#  'prepares': 687,
#  'platform': 688,
#  'toys': 689,
#  'empty': 690,
#  'onlookers': 691,
#  'hits': 692,
#  'wide': 693,
#  'talks': 694,
#  'rain': 695,
#  'gravel': 696,
#  'shop': 697,
#  'gold': 698,
#  'do': 699,
#  'signs': 700,
#  'bride': 701,
#  'paddling': 702,
#  'waving': 703,
#  'snowcovered': 704,
#  'heads': 705,
#  'public': 706,
#  'naked': 707,
#  'wear': 708,
#  'rough': 709,
#  'just': 710,
#  'ladies': 711,
#  'among': 712,
#  'base': 713,
#  'mohawk': 714,
#  'market': 715,
#  'headband': 716,
#  'birds': 717,
#  'pavement': 718,
#  'facing': 719,
#  'reads': 720,
#  'having': 721,
#  'traffic': 722,
#  'plaid': 723,
#  'branch': 724,
#  'neck': 725,
#  'downhill': 726,
#  'skateboards': 727,
#  'cream': 728,
#  'african': 729,
#  'hose': 730,
#  'thrown': 731,
#  'cross': 732,
#  'drives': 733,
#  'dirty': 734,
#  'bars': 735,
#  'wings': 736,
#  'scene': 737,
#  'bottom': 738,
#  'fenced': 739,
#  'races': 740,
#  'different': 741,
#  'painting': 742,
#  'lies': 743,
#  'beer': 744,
#  'wait': 745,
#  'indoor': 746,
#  'barefoot': 747,
#  'chewing': 748,
#  'cricket': 749,
#  'goalie': 750,
#  'resting': 751,
#  'splash': 752,
#  'carpet': 753,
#  'says': 754,
#  'waits': 755,
#  'fall': 756,
#  'bearded': 757,
#  'carnival': 758,
#  'kitchen': 759,
#  'school': 760,
#  'rapids': 761,
#  'blows': 762,
#  'wedding': 763,
#  'wrestler': 764,
#  'match': 765,
#  'paved': 766,
#  'balloon': 767,
#  'lit': 768,
#  'rural': 769,
#  'creek': 770,
#  'teeth': 771,
#  'onstage': 772,
#  'stadium': 773,
#  'opposing': 774,
#  'moving': 775,
#  'paddle': 776,
#  'mother': 777,
#  'display': 778,
#  'lap': 779,
#  'younger': 780,
#  'filled': 781,
#  'greyhounds': 782,
#  'santa': 783,
#  'smoke': 784,
#  'hula': 785,
#  'landscape': 786,
#  'atv': 787,
#  'gun': 788,
#  'video': 789,
#  'pulled': 790,
#  'animals': 791,
#  'motorbike': 792,
#  'talk': 793,
#  'shoulder': 794,
#  'showing': 795,
#  'before': 796,
#  'skates': 797,
#  'falls': 798,
#  'shooting': 799,
#  'art': 800,
#  'boats': 801,
#  'foot': 802,
#  'plants': 803,
#  'headphones': 804,
#  'chase': 805,
#  'matching': 806,
#  'reaching': 807,
#  'block': 808,
#  'gloves': 809,
#  'hay': 810,
#  'staircase': 811,
#  'can': 812,
#  'ropes': 813,
#  'floating': 814,
#  'deck': 815,
#  'where': 816,
#  'mouths': 817,
#  'fair': 818,
#  'try': 819,
#  'unicycle': 820,
#  'reaches': 821,
#  'pipe': 822,
#  'wire': 823,
#  'seated': 824,
#  'retriever': 825,
#  'urban': 826,
#  'parked': 827,
#  'pack': 828,
#  'martial': 829,
#  'close': 830,
#  'instruments': 831,
#  'singing': 832,
#  'bubble': 833,
#  'runner': 834,
#  'teenagers': 835,
#  'christmas': 836,
#  'spotted': 837,
#  'shakes': 838,
#  'skiers': 839,
#  'audience': 840,
#  'amusement': 841,
#  'poodle': 842,
#  'formation': 843,
#  'bandanna': 844,
#  'pulls': 845,
#  'multicolored': 846,
#  'wheelie': 847,
#  'digging': 848,
#  'lights': 849,
#  'surfs': 850,
#  'grinding': 851,
#  'flight': 852,
#  'duck': 853,
#  'hole': 854,
#  'outstretched': 855,
#  'lined': 856,
#  'fly': 857,
#  'hikers': 858,
#  'atop': 859,
#  'helmets': 860,
#  'hitting': 861,
#  'purse': 862,
#  'follows': 863,
#  'funny': 864,
#  'shoulders': 865,
#  'kite': 866,
#  'covering': 867,
#  'raises': 868,
#  'perform': 869,
#  'giant': 870,
#  'row': 871,
#  'newspaper': 872,
#  'puts': 873,
#  'spray': 874,
#  'alone': 875,
#  'stop': 876,
#  'preparing': 877,
#  'bank': 878,
#  'photograph': 879,
#  'ear': 880,
#  'enjoys': 881,
#  'bushes': 882,
#  'hoodie': 883,
#  'balancing': 884,
#  'curly': 885,
#  'muzzled': 886,
#  'rodeo': 887,
#  'jumped': 888,
#  'rowing': 889,
#  'kneeling': 890,
#  'paddles': 891,
#  'pier': 892,
#  'alongside': 893,
#  'backwards': 894,
#  'music': 895,
#  'jeep': 896,
#  'parachute': 897,
#  'muzzle': 898,
#  'putting': 899,
#  'hang': 900,
#  'pull': 901,
#  'laughs': 902,
#  'station': 903,
#  'giving': 904,
#  'writing': 905,
#  'gives': 906,
#  'cold': 907,
#  'tie': 908,
#  'denim': 909,
#  'owner': 910,
#  'indoors': 911,
#  'spinning': 912,
#  'plate': 913,
#  'himself': 914,
#  'gate': 915,
#  'bite': 916,
#  'chain': 917,
#  'riders': 918,
#  'bites': 919,
#  'break': 920,
#  'appears': 921,
#  'safety': 922,
#  'handrail': 923,
#  'playfully': 924,
#  'fetch': 925,
#  'finger': 926,
#  'brightly': 927,
#  'bikers': 928,
#  'picnic': 929,
#  'makeup': 930,
#  'underneath': 931,
#  'competing': 932,
#  'mound': 933,
#  'licking': 934,
#  'tackle': 935,
#  'terrier': 936,
#  'seven': 937,
#  'rink': 938,
#  'construction': 939,
#  'paws': 940,
#  'shows': 941,
#  'machine': 942,
#  'collie': 943,
#  'these': 944,
#  'shaggy': 945,
#  'foreground': 946,
#  'ladder': 947,
#  'hillside': 948,
#  'referee': 949,
#  'enjoying': 950,
#  'roller': 951,
#  'necklace': 952,
#  'backs': 953,
#  'larger': 954,
#  'professional': 955,
#  'doorway': 956,
#  'passing': 957,
#  'bowl': 958,
#  'waters': 959,
#  'kayaking': 960,
#  'terrain': 961,
#  'quickly': 962,
#  'helps': 963,
#  'half': 964,
#  'tug': 965,
#  'backpacks': 966,
#  'step': 967,
#  'hooded': 968,
#  'float': 969,
#  'splashed': 970,
#  'jungle': 971,
#  'taken': 972,
#  'balances': 973,
#  'made': 974,
#  'lean': 975,
#  'skater': 976,
#  'third': 977,
#  'counter': 978,
#  'homeless': 979,
#  'sniffing': 980,
#  'shadow': 981,
#  'hoops': 982,
#  'caught': 983,
#  'friend': 984,
#  'pigeons': 985,
#  'violin': 986,
#  'fingers': 987,
#  'military': 988,
#  'wheelchair': 989,
#  'basket': 990,
#  'round': 991,
#  'spots': 992,
#  'courtyard': 993,
#  'crouches': 994,
#  'streets': 995,
#  'bouncing': 996,
#  'biking': 997,
#  'leap': 998,
#  'straw': 999,
#  'computer': 1000,
#  ...}

# %%
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 8586

# %%
all_image_ids = os.listdir(images_directory)

train_image_ids, val_image_ids = train_test_split(all_image_ids, test_size=0.15, random_state=42)
val_image_ids, test_image_ids = train_test_split(val_image_ids, test_size=0.1, random_state=42)

train_captions, val_captions, test_captions = [], [], []
for caption in captions_IDs:
    image_id, _ = caption.split('\t')

    if image_id in train_image_ids:
        train_captions.append(caption)

    elif image_id in val_image_ids:
        val_captions.append(caption)

    elif image_id in test_image_ids:
        test_captions.append(caption)

    else:
        print('Unknown image ID !')

train_captions[0], val_captions[0], test_captions[0], len(train_captions)/5, len(val_captions)/5, len(test_captions)/5
# Out:
# ('1000268201_693b08cb0e.jpg\tstart a child in a pink dress is climbing up a set of stairs in an entry way end\n',
#  '1007129816_e794419615.jpg\tstart a man in an orange hat starring at something end\n',
#  '1213336750_2269b51397.jpg\tstart a man in a black jacket is taking a photo of a man in a red jacket end\n',
#  6877.0,
#  1092.0,
#  122.0)

# %%
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(299, 299))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img

def extract_image_features(model, image_path):
    img = preprocess_image(image_path)
    features = model.predict(img, verbose=0)
    return features

inception_v3_model = InceptionV3(weights = 'imagenet', input_shape=(299, 299, 3))

# %%
inception_v3_model.output_shape
# Out:
# (None, 1000)

# %%
inception_v3_model.layers
# Out:
# [<InputLayer name=input_layer_3, built=True>,
#  <Conv2D name=conv2d_282, built=True>,
#  <BatchNormalization name=batch_normalization_282, built=True>,
#  <Activation name=activation_282, built=True>,
#  <Conv2D name=conv2d_283, built=True>,
#  <BatchNormalization name=batch_normalization_283, built=True>,
#  <Activation name=activation_283, built=True>,
#  <Conv2D name=conv2d_284, built=True>,
#  <BatchNormalization name=batch_normalization_284, built=True>,
#  <Activation name=activation_284, built=True>,
#  <MaxPooling2D name=max_pooling2d_12, built=True>,
#  <Conv2D name=conv2d_285, built=True>,
#  <BatchNormalization name=batch_normalization_285, built=True>,
#  <Activation name=activation_285, built=True>,
#  <Conv2D name=conv2d_286, built=True>,
#  <BatchNormalization name=batch_normalization_286, built=True>,
#  <Activation name=activation_286, built=True>,
#  <MaxPooling2D name=max_pooling2d_13, built=True>,
#  <Conv2D name=conv2d_290, built=True>,
#  <BatchNormalization name=batch_normalization_290, built=True>,
#  <Activation name=activation_290, built=True>,
#  <Conv2D name=conv2d_288, built=True>,
#  <Conv2D name=conv2d_291, built=True>,
#  <BatchNormalization name=batch_normalization_288, built=True>,
#  <BatchNormalization name=batch_normalization_291, built=True>,
#  <Activation name=activation_288, built=True>,
#  <Activation name=activation_291, built=True>,
#  <AveragePooling2D name=average_pooling2d_27, built=True>,
#  <Conv2D name=conv2d_287, built=True>,
#  <Conv2D name=conv2d_289, built=True>,
#  <Conv2D name=conv2d_292, built=True>,
#  <Conv2D name=conv2d_293, built=True>,
#  <BatchNormalization name=batch_normalization_287, built=True>,
#  <BatchNormalization name=batch_normalization_289, built=True>,
#  <BatchNormalization name=batch_normalization_292, built=True>,
#  <BatchNormalization name=batch_normalization_293, built=True>,
#  <Activation name=activation_287, built=True>,
#  <Activation name=activation_289, built=True>,
#  <Activation name=activation_292, built=True>,
#  <Activation name=activation_293, built=True>,
#  <Concatenate name=mixed0, built=True>,
#  <Conv2D name=conv2d_297, built=True>,
#  <BatchNormalization name=batch_normalization_297, built=True>,
#  <Activation name=activation_297, built=True>,
#  <Conv2D name=conv2d_295, built=True>,
#  <Conv2D name=conv2d_298, built=True>,
#  <BatchNormalization name=batch_normalization_295, built=True>,
#  <BatchNormalization name=batch_normalization_298, built=True>,
#  <Activation name=activation_295, built=True>,
#  <Activation name=activation_298, built=True>,
#  <AveragePooling2D name=average_pooling2d_28, built=True>,
#  <Conv2D name=conv2d_294, built=True>,
#  <Conv2D name=conv2d_296, built=True>,
#  <Conv2D name=conv2d_299, built=True>,
#  <Conv2D name=conv2d_300, built=True>,
#  <BatchNormalization name=batch_normalization_294, built=True>,
#  <BatchNormalization name=batch_normalization_296, built=True>,
#  <BatchNormalization name=batch_normalization_299, built=True>,
#  <BatchNormalization name=batch_normalization_300, built=True>,
#  <Activation name=activation_294, built=True>,
#  <Activation name=activation_296, built=True>,
#  <Activation name=activation_299, built=True>,
#  <Activation name=activation_300, built=True>,
#  <Concatenate name=mixed1, built=True>,
#  <Conv2D name=conv2d_304, built=True>,
#  <BatchNormalization name=batch_normalization_304, built=True>,
#  <Activation name=activation_304, built=True>,
#  <Conv2D name=conv2d_302, built=True>,
#  <Conv2D name=conv2d_305, built=True>,
#  <BatchNormalization name=batch_normalization_302, built=True>,
#  <BatchNormalization name=batch_normalization_305, built=True>,
#  <Activation name=activation_302, built=True>,
#  <Activation name=activation_305, built=True>,
#  <AveragePooling2D name=average_pooling2d_29, built=True>,
#  <Conv2D name=conv2d_301, built=True>,
#  <Conv2D name=conv2d_303, built=True>,
#  <Conv2D name=conv2d_306, built=True>,
#  <Conv2D name=conv2d_307, built=True>,
#  <BatchNormalization name=batch_normalization_301, built=True>,
#  <BatchNormalization name=batch_normalization_303, built=True>,
#  <BatchNormalization name=batch_normalization_306, built=True>,
#  <BatchNormalization name=batch_normalization_307, built=True>,
#  <Activation name=activation_301, built=True>,
#  <Activation name=activation_303, built=True>,
#  <Activation name=activation_306, built=True>,
#  <Activation name=activation_307, built=True>,
#  <Concatenate name=mixed2, built=True>,
#  <Conv2D name=conv2d_309, built=True>,
#  <BatchNormalization name=batch_normalization_309, built=True>,
#  <Activation name=activation_309, built=True>,
#  <Conv2D name=conv2d_310, built=True>,
#  <BatchNormalization name=batch_normalization_310, built=True>,
#  <Activation name=activation_310, built=True>,
#  <Conv2D name=conv2d_308, built=True>,
#  <Conv2D name=conv2d_311, built=True>,
#  <BatchNormalization name=batch_normalization_308, built=True>,
#  <BatchNormalization name=batch_normalization_311, built=True>,
#  <Activation name=activation_308, built=True>,
#  <Activation name=activation_311, built=True>,
#  <MaxPooling2D name=max_pooling2d_14, built=True>,
#  <Concatenate name=mixed3, built=True>,
#  <Conv2D name=conv2d_316, built=True>,
#  <BatchNormalization name=batch_normalization_316, built=True>,
#  <Activation name=activation_316, built=True>,
#  <Conv2D name=conv2d_317, built=True>,
#  <BatchNormalization name=batch_normalization_317, built=True>,
#  <Activation name=activation_317, built=True>,
#  <Conv2D name=conv2d_313, built=True>,
#  <Conv2D name=conv2d_318, built=True>,
#  <BatchNormalization name=batch_normalization_313, built=True>,
#  <BatchNormalization name=batch_normalization_318, built=True>,
#  <Activation name=activation_313, built=True>,
#  <Activation name=activation_318, built=True>,
#  <Conv2D name=conv2d_314, built=True>,
#  <Conv2D name=conv2d_319, built=True>,
#  <BatchNormalization name=batch_normalization_314, built=True>,
#  <BatchNormalization name=batch_normalization_319, built=True>,
#  <Activation name=activation_314, built=True>,
#  <Activation name=activation_319, built=True>,
#  <AveragePooling2D name=average_pooling2d_30, built=True>,
#  <Conv2D name=conv2d_312, built=True>,
#  <Conv2D name=conv2d_315, built=True>,
#  <Conv2D name=conv2d_320, built=True>,
#  <Conv2D name=conv2d_321, built=True>,
#  <BatchNormalization name=batch_normalization_312, built=True>,
#  <BatchNormalization name=batch_normalization_315, built=True>,
#  <BatchNormalization name=batch_normalization_320, built=True>,
#  <BatchNormalization name=batch_normalization_321, built=True>,
#  <Activation name=activation_312, built=True>,
#  <Activation name=activation_315, built=True>,
#  <Activation name=activation_320, built=True>,
#  <Activation name=activation_321, built=True>,
#  <Concatenate name=mixed4, built=True>,
#  <Conv2D name=conv2d_326, built=True>,
#  <BatchNormalization name=batch_normalization_326, built=True>,
#  <Activation name=activation_326, built=True>,
#  <Conv2D name=conv2d_327, built=True>,
#  <BatchNormalization name=batch_normalization_327, built=True>,
#  <Activation name=activation_327, built=True>,
#  <Conv2D name=conv2d_323, built=True>,
#  <Conv2D name=conv2d_328, built=True>,
#  <BatchNormalization name=batch_normalization_323, built=True>,
#  <BatchNormalization name=batch_normalization_328, built=True>,
#  <Activation name=activation_323, built=True>,
#  <Activation name=activation_328, built=True>,
#  <Conv2D name=conv2d_324, built=True>,
#  <Conv2D name=conv2d_329, built=True>,
#  <BatchNormalization name=batch_normalization_324, built=True>,
#  <BatchNormalization name=batch_normalization_329, built=True>,
#  <Activation name=activation_324, built=True>,
#  <Activation name=activation_329, built=True>,
#  <AveragePooling2D name=average_pooling2d_31, built=True>,
#  <Conv2D name=conv2d_322, built=True>,
#  <Conv2D name=conv2d_325, built=True>,
#  <Conv2D name=conv2d_330, built=True>,
#  <Conv2D name=conv2d_331, built=True>,
#  <BatchNormalization name=batch_normalization_322, built=True>,
#  <BatchNormalization name=batch_normalization_325, built=True>,
#  <BatchNormalization name=batch_normalization_330, built=True>,
#  <BatchNormalization name=batch_normalization_331, built=True>,
#  <Activation name=activation_322, built=True>,
#  <Activation name=activation_325, built=True>,
#  <Activation name=activation_330, built=True>,
#  <Activation name=activation_331, built=True>,
#  <Concatenate name=mixed5, built=True>,
#  <Conv2D name=conv2d_336, built=True>,
#  <BatchNormalization name=batch_normalization_336, built=True>,
#  <Activation name=activation_336, built=True>,
#  <Conv2D name=conv2d_337, built=True>,
#  <BatchNormalization name=batch_normalization_337, built=True>,
#  <Activation name=activation_337, built=True>,
#  <Conv2D name=conv2d_333, built=True>,
#  <Conv2D name=conv2d_338, built=True>,
#  <BatchNormalization name=batch_normalization_333, built=True>,
#  <BatchNormalization name=batch_normalization_338, built=True>,
#  <Activation name=activation_333, built=True>,
#  <Activation name=activation_338, built=True>,
#  <Conv2D name=conv2d_334, built=True>,
#  <Conv2D name=conv2d_339, built=True>,
#  <BatchNormalization name=batch_normalization_334, built=True>,
#  <BatchNormalization name=batch_normalization_339, built=True>,
#  <Activation name=activation_334, built=True>,
#  <Activation name=activation_339, built=True>,
#  <AveragePooling2D name=average_pooling2d_32, built=True>,
#  <Conv2D name=conv2d_332, built=True>,
#  <Conv2D name=conv2d_335, built=True>,
#  <Conv2D name=conv2d_340, built=True>,
#  <Conv2D name=conv2d_341, built=True>,
#  <BatchNormalization name=batch_normalization_332, built=True>,
#  <BatchNormalization name=batch_normalization_335, built=True>,
#  <BatchNormalization name=batch_normalization_340, built=True>,
#  <BatchNormalization name=batch_normalization_341, built=True>,
#  <Activation name=activation_332, built=True>,
#  <Activation name=activation_335, built=True>,
#  <Activation name=activation_340, built=True>,
#  <Activation name=activation_341, built=True>,
#  <Concatenate name=mixed6, built=True>,
#  <Conv2D name=conv2d_346, built=True>,
#  <BatchNormalization name=batch_normalization_346, built=True>,
#  <Activation name=activation_346, built=True>,
#  <Conv2D name=conv2d_347, built=True>,
#  <BatchNormalization name=batch_normalization_347, built=True>,
#  <Activation name=activation_347, built=True>,
#  <Conv2D name=conv2d_343, built=True>,
#  <Conv2D name=conv2d_348, built=True>,
#  <BatchNormalization name=batch_normalization_343, built=True>,
#  <BatchNormalization name=batch_normalization_348, built=True>,
#  <Activation name=activation_343, built=True>,
#  <Activation name=activation_348, built=True>,
#  <Conv2D name=conv2d_344, built=True>,
#  <Conv2D name=conv2d_349, built=True>,
#  <BatchNormalization name=batch_normalization_344, built=True>,
#  <BatchNormalization name=batch_normalization_349, built=True>,
#  <Activation name=activation_344, built=True>,
#  <Activation name=activation_349, built=True>,
#  <AveragePooling2D name=average_pooling2d_33, built=True>,
#  <Conv2D name=conv2d_342, built=True>,
#  <Conv2D name=conv2d_345, built=True>,
#  <Conv2D name=conv2d_350, built=True>,
#  <Conv2D name=conv2d_351, built=True>,
#  <BatchNormalization name=batch_normalization_342, built=True>,
#  <BatchNormalization name=batch_normalization_345, built=True>,
#  <BatchNormalization name=batch_normalization_350, built=True>,
#  <BatchNormalization name=batch_normalization_351, built=True>,
#  <Activation name=activation_342, built=True>,
#  <Activation name=activation_345, built=True>,
#  <Activation name=activation_350, built=True>,
#  <Activation name=activation_351, built=True>,
#  <Concatenate name=mixed7, built=True>,
#  <Conv2D name=conv2d_354, built=True>,
#  <BatchNormalization name=batch_normalization_354, built=True>,
#  <Activation name=activation_354, built=True>,
#  <Conv2D name=conv2d_355, built=True>,
#  <BatchNormalization name=batch_normalization_355, built=True>,
#  <Activation name=activation_355, built=True>,
#  <Conv2D name=conv2d_352, built=True>,
#  <Conv2D name=conv2d_356, built=True>,
#  <BatchNormalization name=batch_normalization_352, built=True>,
#  <BatchNormalization name=batch_normalization_356, built=True>,
#  <Activation name=activation_352, built=True>,
#  <Activation name=activation_356, built=True>,
#  <Conv2D name=conv2d_353, built=True>,
#  <Conv2D name=conv2d_357, built=True>,
#  <BatchNormalization name=batch_normalization_353, built=True>,
#  <BatchNormalization name=batch_normalization_357, built=True>,
#  <Activation name=activation_353, built=True>,
#  <Activation name=activation_357, built=True>,
#  <MaxPooling2D name=max_pooling2d_15, built=True>,
#  <Concatenate name=mixed8, built=True>,
#  <Conv2D name=conv2d_362, built=True>,
#  <BatchNormalization name=batch_normalization_362, built=True>,
#  <Activation name=activation_362, built=True>,
#  <Conv2D name=conv2d_359, built=True>,
#  <Conv2D name=conv2d_363, built=True>,
#  <BatchNormalization name=batch_normalization_359, built=True>,
#  <BatchNormalization name=batch_normalization_363, built=True>,
#  <Activation name=activation_359, built=True>,
#  <Activation name=activation_363, built=True>,
#  <Conv2D name=conv2d_360, built=True>,
#  <Conv2D name=conv2d_361, built=True>,
#  <Conv2D name=conv2d_364, built=True>,
#  <Conv2D name=conv2d_365, built=True>,
#  <AveragePooling2D name=average_pooling2d_34, built=True>,
#  <Conv2D name=conv2d_358, built=True>,
#  <BatchNormalization name=batch_normalization_360, built=True>,
#  <BatchNormalization name=batch_normalization_361, built=True>,
#  <BatchNormalization name=batch_normalization_364, built=True>,
#  <BatchNormalization name=batch_normalization_365, built=True>,
#  <Conv2D name=conv2d_366, built=True>,
#  <BatchNormalization name=batch_normalization_358, built=True>,
#  <Activation name=activation_360, built=True>,
#  <Activation name=activation_361, built=True>,
#  <Activation name=activation_364, built=True>,
#  <Activation name=activation_365, built=True>,
#  <BatchNormalization name=batch_normalization_366, built=True>,
#  <Activation name=activation_358, built=True>,
#  <Concatenate name=mixed9_0, built=True>,
#  <Concatenate name=concatenate_6, built=True>,
#  <Activation name=activation_366, built=True>,
#  <Concatenate name=mixed9, built=True>,
#  <Conv2D name=conv2d_371, built=True>,
#  <BatchNormalization name=batch_normalization_371, built=True>,
#  <Activation name=activation_371, built=True>,
#  <Conv2D name=conv2d_368, built=True>,
#  <Conv2D name=conv2d_372, built=True>,
#  <BatchNormalization name=batch_normalization_368, built=True>,
#  <BatchNormalization name=batch_normalization_372, built=True>,
#  <Activation name=activation_368, built=True>,
#  <Activation name=activation_372, built=True>,
#  <Conv2D name=conv2d_369, built=True>,
#  <Conv2D name=conv2d_370, built=True>,
#  <Conv2D name=conv2d_373, built=True>,
#  <Conv2D name=conv2d_374, built=True>,
#  <AveragePooling2D name=average_pooling2d_35, built=True>,
#  <Conv2D name=conv2d_367, built=True>,
#  <BatchNormalization name=batch_normalization_369, built=True>,
#  <BatchNormalization name=batch_normalization_370, built=True>,
#  <BatchNormalization name=batch_normalization_373, built=True>,
#  <BatchNormalization name=batch_normalization_374, built=True>,
#  <Conv2D name=conv2d_375, built=True>,
#  <BatchNormalization name=batch_normalization_367, built=True>,
#  <Activation name=activation_369, built=True>,
#  <Activation name=activation_370, built=True>,
#  <Activation name=activation_373, built=True>,
#  <Activation name=activation_374, built=True>,
#  <BatchNormalization name=batch_normalization_375, built=True>,
#  <Activation name=activation_367, built=True>,
#  <Concatenate name=mixed9_1, built=True>,
#  <Concatenate name=concatenate_7, built=True>,
#  <Activation name=activation_375, built=True>,
#  <Concatenate name=mixed10, built=True>,
#  <GlobalAveragePooling2D name=avg_pool, built=True>,
#  <Dense name=predictions, built=True>]

# %%
inception_v3_model.layers.pop()
inception_v3_model = Model(inputs=inception_v3_model.inputs, outputs=inception_v3_model.layers[-2].output)

# %%
inception_v3_model.output_shape
# Out:
# (None, 2048)

# %%
train_image_features, val_image_features, test_image_features = {}, {}, {}  # A Dictionary to store image features with their corresponding IDs

pbar = tqdm_notebook(total=len(all_image_ids), position=0, leave=True, colour='green')

for caption in all_image_ids:
    image_id = caption.split('\t')[0]
    image_path = os.path.join(images_directory, image_id)
    image_features = extract_image_features(inception_v3_model, image_path) # Extracting features

    if image_id in train_image_ids:
        train_image_features[image_id] = image_features.flatten()  # Flattening the features
        pbar.update(1)

    elif image_id in val_image_ids:
        val_image_features[image_id] = image_features.flatten()  # Flattening the features
        pbar.update(1)

    elif image_id in test_image_ids:
        test_image_features[image_id] = image_features.flatten()  # Flattening the features
        pbar.update(1)

    else:
        print('Unknown image ID !')

pbar.close()

# %%
def data_generator(captions, image_features, tokenizer, max_caption_length, batch_size):
    num_samples = len(captions)
    image_ids = list(image_features.keys())
    while True:
        np.random.shuffle(image_ids)  # Shuffle image_ids for each epoch
        for start_idx in range(0, num_samples, batch_size):
            end_idx = min(start_idx + batch_size, num_samples)
            X_images, X_captions, y = [], [], []
            for caption in captions[start_idx:end_idx]:
                image_id, caption_text = caption.split('\t')
                caption_text = caption_text.rstrip('\n')
                seq = tokenizer.texts_to_sequences([caption_text])[0] # Tokenizing the caption
                for i in range(1, len(seq)):
                    in_seq, out_seq = seq[:i], seq[i] # X_caption, Y
                    in_seq = pad_sequences([in_seq], maxlen=max_caption_length)[0]
                    out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
                    X_images.append(image_features[image_id])
                    X_captions.append(in_seq)
                    y.append(out_seq)

            yield [np.array(X_images), np.array(X_captions)], np.array(y)


max_caption_length = max(len(caption.split()) for caption in cleaned_captions) + 1

cnn_output_dim = inception_v3_model.output_shape[1] # 2048

batch_size_train = 270
batch_size_val = 150

train_data_generator = data_generator(train_captions, train_image_features, tokenizer, max_caption_length, batch_size_train)
val_data_generator = data_generator(val_captions, val_image_features, tokenizer, max_caption_length, batch_size_val)

# %%
def build_model(vocab_size, max_caption_length, cnn_output_dim):
    input_image = Input(shape=(cnn_output_dim,), name='Features_Input')
    fe1 = BatchNormalization()(input_image)
    fe2 = Dense(256, activation='relu')(fe1) # Adding a Dense layer to the CNN output to match the decoder output size
    fe3 = BatchNormalization()(fe2)

    input_caption = Input(shape=(max_caption_length,), name='Sequence_Input')
    se1 = Embedding(vocab_size, 256, mask_zero=True)(input_caption)
    se2 = LSTM(256)(se1)

    decoder1 = add([fe3, se2])
    decoder2 = Dense(256, activation='relu')(decoder1)
    outputs = Dense(vocab_size, activation='softmax', name='Output_Layer')(decoder2)

    model = Model(inputs=[input_image, input_caption], outputs=outputs, name='Image_Captioning')
    return model

caption_model = build_model(vocab_size, max_caption_length, cnn_output_dim)

optimizer = Adam(learning_rate=0.01, clipnorm=1.0)
caption_model.compile(loss='categorical_crossentropy', optimizer=optimizer)

caption_model.summary()

# %%
plot_model(caption_model)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

def lr_scheduler(epoch, lr):
    return lr * tf.math.exp(-0.6)

lr_schedule = LearningRateScheduler(lr_scheduler)

history = caption_model.fit(train_data_generator, steps_per_epoch=len(train_captions) // batch_size_train,
                        validation_data=val_data_generator, validation_steps=len(val_captions) // batch_size_val,
                        epochs=15, callbacks=[early_stopping, lr_schedule])

# %%
plt.figure(figsize=(15, 7), dpi=200)
sns.set_style('whitegrid')
plt.plot([x+1 for x in range(len(history.history['loss']))], history.history['loss'], color='#E74C3C', marker='o')
plt.plot([x+1 for x in range(len(history.history['loss']))], history.history['val_loss'], color='#641E16', marker='h')
plt.title('Train VS Validation', fontsize=15, fontweight='bold')
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel('Epoch', fontweight='bold')
plt.ylabel('Loss', fontweight='bold')
plt.legend(['Train Loss', 'Validation Loss'], loc='best')
plt.show()

# %%
def greedy_generator(image_features):
    in_text = 'start '
    for _ in range(max_caption_length):
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        sequence = pad_sequences([sequence], maxlen=max_caption_length).reshape((1,max_caption_length))
        prediction = caption_model.predict([image_features.reshape(1,cnn_output_dim), sequence], verbose=0)
        idx = np.argmax(prediction)
        word = tokenizer.index_word[idx]
        in_text += ' ' + word
        if word == 'end':
            break

    in_text = in_text.replace('start ', '')
    in_text = in_text.replace(' end', '')

    return in_text

# %%
def beam_search_generator(image_features, K_beams = 3, log = False):
    start = [tokenizer.word_index['start']]
    start_word = [[start, 0.0]]
    for _ in range(max_caption_length):
        temp = []
        for s in start_word:
            sequence  = pad_sequences([s[0]], maxlen=max_caption_length).reshape((1,max_caption_length))
            preds = caption_model.predict([image_features.reshape(1,cnn_output_dim), sequence], verbose=0)
            word_preds = np.argsort(preds[0])[-K_beams:]
            for w in word_preds:
                next_cap, prob = s[0][:], s[1]
                next_cap.append(w)
                if log:
                    prob += np.log(preds[0][w]) # assign a probability to each K words
                else:
                    prob += preds[0][w]
                temp.append([next_cap, prob])

        start_word = temp
        start_word = sorted(start_word, reverse=False, key=lambda l: l[1])
        start_word = start_word[-K_beams:]

    start_word = start_word[-1][0]
    captions_ = [tokenizer.index_word[i] for i in start_word]
    final_caption = []
    for i in captions_:
        if i != 'end':
            final_caption.append(i)
        else:
            break

    final_caption = ' '.join(final_caption[1:])
    return final_caption

# %%
def BLEU_score(actual, greedy, beam_search):
    score_greedy_1 = corpus_bleu(actual, greedy, weights=(0.3, 0.3, 0.3, 0))
    score_greedy_2 = corpus_bleu(actual, greedy, weights=(0.25, 0.25, 0.25, 0.25))
    score_BS_1 = corpus_bleu(actual, beam_search, weights=(0.3, 0.3, 0.3, 0))
    score_BS_2 = corpus_bleu(actual, beam_search, weights=(0.25, 0.25, 0.25, 0.25))

    return [
        (f'BLEU-2 Greedy: {round(score_BS_2, 5)}'),
        (f'BLEU-1 Greedy: {round(score_BS_1, 5)}'),
        (f'Greedy: {greedy[0]}'),
        (f'BLEU-2 Beam Search: {round(score_greedy_2, 5)}'),
        (f'BLEU-1 Beam Search: {round(score_greedy_1, 5)}'),
        (f'Beam Search:  {beam_search[0]}')
    ]

# %%
generated_captions = {}

pbar = tqdm_notebook(total=len(test_image_features), position=0, leave=True, colour='green')
for image_id in test_image_features:
    cap = greedy_generator(test_image_features[image_id])
    generated_captions[image_id] = cap
    pbar.update(1)

pbar.close()

# %%
def visualization(data, greedy_caps, beamS_generator, evaluator, num_of_images):
    keys = list(data.keys())
    images = [np.random.choice(keys) for i in range(num_of_images)] # Randomly selected images
    count = 1
    fig = plt.figure(figsize=(6,20))
    for filename in images:
        actual_cap = data[filename]
        actual_cap = [x.replace("start ", "") for x in actual_cap]
        actual_cap = [x.replace(" end", "") for x in actual_cap]

        greedy_cap = greedy_caps[filename]
        beamS_cap = beamS_generator(test_image_features[filename])

        caps_with_score = evaluator(actual_cap, [greedy_cap]*(len(actual_cap)), [beamS_cap]*(len(actual_cap)))

        image_load = load_img(images_directory+filename, target_size=(199,199,3))
        ax = fig.add_subplot(num_of_images,2,count,xticks=[],yticks=[])
        ax.imshow(image_load)
        count += 1

        ax = fig.add_subplot(num_of_images,2,count)
        plt.axis('off')
        ax.plot()
        ax.set_xlim(0,1)
        ax.set_ylim(0,len(caps_with_score))
        for i, text in enumerate(caps_with_score):
            ax.text(0,i,text,fontsize=10)
        count += 1
    plt.show()

visualization(test_actual_captions, generated_captions, beam_search_generator, BLEU_score, 7)
